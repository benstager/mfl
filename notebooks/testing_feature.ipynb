# %%
import seaborn as sns
import os
import pandas as pd

current_dir = os.path.dirname('testing_feature.ipynb')
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
csv_path = os.path.join(parent_dir, "data", "first_round_qb_training_data.csv")

df = pd.read_csv(csv_path)

# %%
df.columns[6:df.shape[1] -1]
# Out:
# Index(['college', 'power_5', 'seasons', 'G', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD',
#        'TD%', 'Int', 'Int%', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate'],
#       dtype='object')

# %%
sns.pairplot(df[df.columns[6:df.shape[1]]], hue="successful", diag_kind="kde", palette="Set2")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...
