# %%
import mfl as mfl
import pandas as pd
import numpy as np
import mfl.api.data_loaders as mfldata
import nfl_data_py as nfl

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, precision_score, precision_recall_curve

from xgboost import XGBClassifier, XGBRFClassifier

from catboost import CatBoostClassifier

import keras
from keras.layers import Dense, ReLU, Bidirectional, Normalization, Dropout, Input
from keras.models import Sequential

import joblib

# %%
mfldata.load_qb_data_cleaned()
# Out:
#      pfr_player_name  round  pick  season     G     Cmp     Att  Cmp%  \
# 0       Sam Bradford      1     1    2010  31.0   604.0   893.0  67.6
# 1          Tim Tebow      1    25    2010  55.0   661.0   995.0  66.4
# 2      Jimmy Clausen      2    48    2010  35.0   695.0  1110.0  62.6
# 3         Colt McCoy      3    85    2010  53.0  1157.0  1645.0  70.3
# 4         Mike Kafka      4   122    2010  30.0   408.0   637.0  64.1
# ..               ...    ...   ...     ...   ...     ...     ...   ...
# 144    C.J. Beathard      3   104    2017   NaN     NaN     NaN   NaN
# 145     Joshua Dobbs      4   135    2017  37.0   614.0   999.0  61.5
# 146  Nathan Peterman      5   171    2017  10.0    20.0    43.0  46.5
# 147       Brad Kaaya      6   215    2017  38.0   721.0  1189.0  60.6
# 148       Chad Kelly      7   253    2017  22.0   503.0   786.0  64.0
#
#          Yds     TD  ...  Int%  Y/A   AY/A   Y/C    Y/G   Rate  seasons  \
# 0     8403.0   88.0  ...   1.8  9.4  10.57  13.9  271.1  175.6      3.0
# 1     9285.0   88.0  ...   1.6  9.3  10.38  14.0  168.8  170.8      4.0
# 2     8148.0   60.0  ...   2.4  7.3   7.33  11.7  232.8  137.2      3.0
# 3    13253.0  112.0  ...   2.7  8.1   8.19  11.5  250.1  155.0      4.0
# 4     4265.0   19.0  ...   3.1  6.7   5.88  10.5  142.2  123.9      4.0
# ..       ...    ...  ...   ...  ...    ...   ...    ...    ...      ...
# 144      NaN    NaN  ...   NaN  NaN    NaN   NaN    NaN    NaN      NaN
# 145   7138.0   53.0  ...   2.9  7.1   6.90  11.6  192.9  133.2      4.0
# 146     94.0    0.0  ...   4.7  2.2   0.09   4.7    9.4   55.6      7.0
# 147   9972.0   69.0  ...   2.0  8.4   8.64  13.8  262.4  146.2      3.0
# 148   6800.0   50.0  ...   2.7  8.7   8.72  13.5  309.1  152.3      7.0
#
#                 name  recent_team seasons_with_draft_team
# 0       Sam Bradford           LA                     4.0
# 1          Tim Tebow          DEN                     2.0
# 2      Jimmy Clausen          CAR                     1.0
# 3         Colt McCoy          CLE                     3.0
# 4         Mike Kafka          PHI                     1.0
# ..               ...          ...                     ...
# 144              NaN          NaN                     NaN
# 145     Joshua Dobbs          PIT                     2.0
# 146  Nathan Peterman          BUF                     2.0
# 147       Brad Kaaya          NaN                     NaN
# 148       Chad Kelly          DEN                     1.0
#
# [149 rows x 22 columns]

# %%
class FranchiseQB:
    def __init__(self, 
                 feature_set='numeric', 
                 model='catboost', 
                 dataset='../data/for_modeling.csv', 
                 **kwargs):
        
        self.feature_set = feature_set
        self.model = model
        self.dataset = dataset
        self.kwargs = kwargs
        self.model_map = {
            'catboost' : CatBoostClassifier(),
            'xgb' : XGBClassifier(), 
            'rf' : RandomForestClassifier(),
            'lr' : LogisticRegression(),
            'hgb' : HistGradientBoostingClassifier(),
            'svm' : SVC(),
            'nn_basic': ...
        }
        self.available_models = list(self.model_map.keys())
        self.model_func = self.model_map[model]
        self.df = pd.read_csv(dataset).dropna()
        self.all_players = self.df['pfr_player_name']

    def create_training_data(self, n_splits=4, stratify=True):
        pass

    def map_response(self, x):
        if x >= 4:
            return 1
        else: 
            return 0
        
    def score(self, y_test, y_probs, y_preds):
        accuracy = accuracy_score(y_test, y_preds)
        f1 = f1_score(y_test, y_preds)
        roc_auc = roc_auc_score(y_test, y_probs)

        metric_dict = {
            'accuracy' : accuracy,
            'f1' : f1,
            'roc_auc': roc_auc
        }

        return metric_dict

    # this needs refinement badly
    def catboost(self, kfold=False, folds=2):
        model = self.model_func
        df = self.df

        if self.feature_set == 'numeric':
            X = df[df.select_dtypes(include='float').columns].drop('seasons_with_draft_team',axis=1)
        elif self.feature_set == 'cat':
            df = df.drop(['name', 'pfr_player_name'], axis=1)
            model = CatBoostClassifier(one_hot_max_size=5, iterations=300, cat_features=df.select_dtypes(include='object').columns.tolist())
            X = df.drop('seasons_with_draft_team', axis=1)
        
        y = df['seasons_with_draft_team'].apply(self.map_response)

        self.X = X
        self.y = y

        k_strat = StratifiedKFold(n_splits=folds, shuffle=False)
        folds = k_strat.split(X, y)
        y_preds = []
        y_probs = []
        y_tests = []
        
        if kfold:
            for train, test in folds:
                
                X_train, X_test = X.iloc[train], X.iloc[test]
                y_train, y_test = y.values[train], y.values[test]    

                model.fit(X_train, y_train)
                y_tests.extend(y_test)
                y_preds.extend(model.predict(X_test))
                y_probs.extend(model.predict_proba(X_test)[:,1])
        
        else:
            X_train, X_test, y_train, y_test = train_test_split(df.drop('seasons_with_draft_team',
                                                                       axis=1),
                                                                       df['seasons_with_draft_team'].apply(self.map_response),
                                                                       test_size=.25,
                                                                       shuffle=True,
                                                                       stratify=df['seasons_with_draft_team'].apply(self.map_response))
            model = CatBoostClassifier(one_hot_max_size=5, iterations=300, cat_features=df.select_dtypes(include='object').columns.tolist())
            model.fit(X_train, y_train)

            y_tests.extend(y_test)
            y_preds.extend(model.predict(X_test))
            y_probs.extend((model.predict_proba(X_test)[:,1]))
        
        self.y_preds = y_preds
        self.y_probs = y_probs
        
        model = CatBoostClassifier(one_hot_max_size=5, iterations=300, cat_features=df.select_dtypes(include='object').columns.tolist())
        model.fit(self.X, self.y)
        self.fit_model = model
        
        metrics = self.score(y_tests, y_probs, y_preds)
        self.model_results = pd.DataFrame(metrics, index=[0])

    def lr(self, **kwargs):
        ...

    def predict_2025_qb(self, player_name, round, pick, recent_team, model='catboost'):
        
        name = player_name
        season = 2020
        model_path = f"/Users/benstager/Desktop/mfl_project/mfl/api/saved_models/{model}_v_0_0.pkl"
        model = joblib.load(model_path)
        

        features = pd.DataFrame({
            'pfr_player_name' : name, 
            'round' : round,
            'pick' : pick,
            'season' : season
        }, index=[0])

        predictors = mfldata.scrape_NFL_REF_QB(player_name=player_name).drop('name')
        processing = pd.concat([features, predictors], axis=1)
        processing['recent_team'] = recent_team

        val = model.predict_proba(processing)
        
        return val

# %%
NFL = FranchiseQB(feature_set='cat', model='catboost')
NFL.predict_2025_qb(player_name='Joe Burrow', round=1, pick=1, recent_team='CIN')
# Out:
# array([[0.81131964, 0.18868036]])

# %%
NFL.model_results
# Out:
#    accuracy        f1   roc_auc
# 0  0.740741  0.222222  0.757143

# %%
model.feature_names_
# Out:
# ['pfr_player_name',
#  'round',
#  'pick',
#  'season',
#  'G',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'Yds',
#  'TD',
#  'TD%',
#  'Int',
#  'Int%',
#  'Y/A',
#  'AY/A',
#  'Y/C',
#  'Y/G',
#  'Rate',
#  'seasons',
#  'name',
#  'recent_team']

# %%
NFL = FranchiseQB(feature_set='cat', model='catboost')
NFL.catboost()
# Out:
# Learning rate set to 0.010625
# 0:	learn: 0.6876656	total: 2.27ms	remaining: 680ms
# 1:	learn: 0.6804419	total: 3.71ms	remaining: 553ms
# 2:	learn: 0.6748704	total: 5.49ms	remaining: 544ms
# 3:	learn: 0.6684385	total: 6.45ms	remaining: 477ms
# 4:	learn: 0.6617654	total: 7.42ms	remaining: 438ms
# 5:	learn: 0.6539512	total: 8.17ms	remaining: 400ms
# 6:	learn: 0.6468635	total: 9.13ms	remaining: 382ms
# 7:	learn: 0.6403487	total: 10.3ms	remaining: 375ms
# 8:	learn: 0.6334392	total: 11.2ms	remaining: 362ms
# 9:	learn: 0.6262633	total: 20.3ms	remaining: 589ms
# 10:	learn: 0.6206962	total: 42.4ms	remaining: 1.11s
# 11:	learn: 0.6153045	total: 43.6ms	remaining: 1.05s
# 12:	learn: 0.6100817	total: 44.5ms	remaining: 982ms
# 13:	learn: 0.6055429	total: 45.2ms	remaining: 924ms
# 14:	learn: 0.6010950	total: 45.9ms	remaining: 872ms
# 15:	learn: 0.5959014	total: 48.7ms	remaining: 864ms
# 16:	learn: 0.5897763	total: 50.9ms	remaining: 847ms
# 17:	learn: 0.5838615	total: 52.6ms	remaining: 824ms
# 18:	learn: 0.5800092	total: 53.2ms	remaining: 786ms
# 19:	learn: 0.5766392	total: 53.9ms	remaining: 754ms
# 20:	learn: 0.5725707	total: 54.5ms	remaining: 724ms
# 21:	learn: 0.5658718	total: 55ms	remaining: 695ms
# 22:	learn: 0.5627346	total: 55.5ms	remaining: 669ms
# 23:	learn: 0.5591580	total: 56.1ms	remaining: 645ms
# 24:	learn: 0.5540379	total: 56.7ms	remaining: 623ms
# 25:	learn: 0.5472530	total: 57.3ms	remaining: 604ms
# 26:	learn: 0.5419133	total: 57.9ms	remaining: 585ms
# 27:	learn: 0.5378634	total: 58.5ms	remaining: 568ms
# 28:	learn: 0.5344856	total: 59.1ms	remaining: 552ms
# 29:	learn: 0.5311810	total: 59.7ms	remaining: 537ms
# 30:	learn: 0.5266576	total: 60.2ms	remaining: 523ms
# 31:	learn: 0.5228382	total: 60.9ms	remaining: 510ms
# 32:	learn: 0.5195818	total: 61.4ms	remaining: 497ms
# 33:	learn: 0.5160247	total: 61.9ms	remaining: 484ms
# 34:	learn: 0.5110546	total: 62.5ms	remaining: 474ms
# 35:	learn: 0.5074919	total: 63.3ms	remaining: 464ms
# 36:	learn: 0.5044501	total: 64ms	remaining: 455ms
# 37:	learn: 0.5000656	total: 64.9ms	remaining: 447ms
# 38:	learn: 0.4962041	total: 65.6ms	remaining: 439ms
# 39:	learn: 0.4939905	total: 66.3ms	remaining: 431ms
# 40:	learn: 0.4901392	total: 66.8ms	remaining: 422ms
# 41:	learn: 0.4864425	total: 67.4ms	remaining: 414ms
# 42:	learn: 0.4820828	total: 68ms	remaining: 407ms
# 43:	learn: 0.4783191	total: 68.6ms	remaining: 399ms
# 44:	learn: 0.4751233	total: 69.2ms	remaining: 392ms
# 45:	learn: 0.4707353	total: 69.7ms	remaining: 385ms
# 46:	learn: 0.4681778	total: 70.3ms	remaining: 378ms
# 47:	learn: 0.4633688	total: 70.9ms	remaining: 372ms
# 48:	learn: 0.4601565	total: 71.6ms	remaining: 367ms
# 49:	learn: 0.4561353	total: 72.3ms	remaining: 361ms
# 50:	learn: 0.4532648	total: 72.9ms	remaining: 356ms
# 51:	learn: 0.4491667	total: 73.4ms	remaining: 350ms
# 52:	learn: 0.4448567	total: 74.1ms	remaining: 346ms
# 53:	learn: 0.4428261	total: 74.6ms	remaining: 340ms
# 54:	learn: 0.4378647	total: 75.1ms	remaining: 335ms
# 55:	learn: 0.4351109	total: 75.7ms	remaining: 330ms
# 56:	learn: 0.4323143	total: 76.2ms	remaining: 325ms
# 57:	learn: 0.4310498	total: 77.1ms	remaining: 322ms
# 58:	learn: 0.4276446	total: 77.7ms	remaining: 317ms
# 59:	learn: 0.4246903	total: 78.4ms	remaining: 314ms
# 60:	learn: 0.4210963	total: 79ms	remaining: 310ms
# 61:	learn: 0.4191321	total: 79.6ms	remaining: 306ms
# 62:	learn: 0.4155206	total: 80.2ms	remaining: 302ms
# 63:	learn: 0.4133607	total: 80.8ms	remaining: 298ms
# 64:	learn: 0.4107758	total: 81.5ms	remaining: 295ms
# 65:	learn: 0.4083414	total: 82.2ms	remaining: 291ms
# 66:	learn: 0.4060808	total: 83.5ms	remaining: 291ms
# 67:	learn: 0.4027130	total: 84.2ms	remaining: 287ms
# 68:	learn: 0.3994951	total: 84.7ms	remaining: 284ms
# 69:	learn: 0.3967938	total: 85.2ms	remaining: 280ms
# 70:	learn: 0.3941014	total: 85.8ms	remaining: 277ms
# 71:	learn: 0.3921616	total: 86.3ms	remaining: 273ms
# 72:	learn: 0.3891019	total: 86.9ms	remaining: 270ms
# 73:	learn: 0.3858641	total: 87.4ms	remaining: 267ms
# 74:	learn: 0.3827901	total: 87.9ms	remaining: 264ms
# 75:	learn: 0.3815471	total: 88.4ms	remaining: 260ms
# 76:	learn: 0.3805816	total: 89ms	remaining: 258ms
# 77:	learn: 0.3781801	total: 89.7ms	remaining: 255ms
# 78:	learn: 0.3753609	total: 90.4ms	remaining: 253ms
# 79:	learn: 0.3724372	total: 91ms	remaining: 250ms
# 80:	learn: 0.3720996	total: 91.3ms	remaining: 247ms
# 81:	learn: 0.3691000	total: 91.9ms	remaining: 244ms
# 82:	learn: 0.3666947	total: 92.6ms	remaining: 242ms
# 83:	learn: 0.3643476	total: 93.2ms	remaining: 240ms
# 84:	learn: 0.3626385	total: 93.8ms	remaining: 237ms
# 85:	learn: 0.3603688	total: 94.3ms	remaining: 235ms
# 86:	learn: 0.3580151	total: 94.8ms	remaining: 232ms
# 87:	learn: 0.3560112	total: 95.6ms	remaining: 230ms
# 88:	learn: 0.3541283	total: 96.1ms	remaining: 228ms
# 89:	learn: 0.3513013	total: 97.2ms	remaining: 227ms
# 90:	learn: 0.3496544	total: 97.8ms	remaining: 225ms
# 91:	learn: 0.3472121	total: 98.4ms	remaining: 223ms
# 92:	learn: 0.3469531	total: 98.7ms	remaining: 220ms
# 93:	learn: 0.3448695	total: 99.5ms	remaining: 218ms
# 94:	learn: 0.3437184	total: 100ms	remaining: 216ms
# 95:	learn: 0.3413212	total: 101ms	remaining: 214ms
# 96:	learn: 0.3395526	total: 101ms	remaining: 212ms
# 97:	learn: 0.3386973	total: 101ms	remaining: 209ms
# 98:	learn: 0.3372112	total: 102ms	remaining: 207ms
# 99:	learn: 0.3354324	total: 103ms	remaining: 205ms
# 100:	learn: 0.3327033	total: 103ms	remaining: 203ms
# 101:	learn: 0.3308804	total: 104ms	remaining: 201ms
# 102:	learn: 0.3304754	total: 104ms	remaining: 199ms
# 103:	learn: 0.3291439	total: 104ms	remaining: 197ms
# 104:	learn: 0.3270305	total: 105ms	remaining: 195ms
# 105:	learn: 0.3254586	total: 105ms	remaining: 193ms
# 106:	learn: 0.3227619	total: 106ms	remaining: 191ms
# 107:	learn: 0.3204806	total: 107ms	remaining: 190ms
# 108:	learn: 0.3197598	total: 107ms	remaining: 188ms
# 109:	learn: 0.3182659	total: 108ms	remaining: 186ms
# 110:	learn: 0.3169593	total: 108ms	remaining: 185ms
# 111:	learn: 0.3154159	total: 109ms	remaining: 183ms
# 112:	learn: 0.3140279	total: 109ms	remaining: 181ms
# 113:	learn: 0.3124250	total: 110ms	remaining: 180ms
# 114:	learn: 0.3102792	total: 111ms	remaining: 178ms
# 115:	learn: 0.3090710	total: 111ms	remaining: 177ms
# 116:	learn: 0.3065602	total: 112ms	remaining: 175ms
# 117:	learn: 0.3043391	total: 113ms	remaining: 174ms
# 118:	learn: 0.3021481	total: 113ms	remaining: 172ms
# 119:	learn: 0.3001281	total: 114ms	remaining: 171ms
# 120:	learn: 0.2984698	total: 114ms	remaining: 169ms
# 121:	learn: 0.2976513	total: 115ms	remaining: 168ms
# 122:	learn: 0.2953737	total: 115ms	remaining: 166ms
# 123:	learn: 0.2940360	total: 116ms	remaining: 165ms
# 124:	learn: 0.2928402	total: 117ms	remaining: 163ms
# 125:	learn: 0.2910593	total: 117ms	remaining: 162ms
# 126:	learn: 0.2891620	total: 118ms	remaining: 160ms
# 127:	learn: 0.2874162	total: 118ms	remaining: 159ms
# 128:	learn: 0.2847977	total: 119ms	remaining: 158ms
# 129:	learn: 0.2838910	total: 119ms	remaining: 156ms
# 130:	learn: 0.2825894	total: 120ms	remaining: 155ms
# 131:	learn: 0.2814272	total: 120ms	remaining: 153ms
# 132:	learn: 0.2803741	total: 121ms	remaining: 152ms
# 133:	learn: 0.2784170	total: 121ms	remaining: 150ms
# 134:	learn: 0.2769030	total: 122ms	remaining: 149ms
# 135:	learn: 0.2754281	total: 123ms	remaining: 148ms
# 136:	learn: 0.2734219	total: 123ms	remaining: 146ms
# 137:	learn: 0.2719554	total: 124ms	remaining: 145ms
# 138:	learn: 0.2708599	total: 124ms	remaining: 144ms
# 139:	learn: 0.2696468	total: 125ms	remaining: 142ms
# 140:	learn: 0.2683755	total: 125ms	remaining: 141ms
# 141:	learn: 0.2672069	total: 126ms	remaining: 140ms
# 142:	learn: 0.2652415	total: 126ms	remaining: 139ms
# 143:	learn: 0.2637280	total: 127ms	remaining: 138ms
# 144:	learn: 0.2618042	total: 128ms	remaining: 136ms
# 145:	learn: 0.2604840	total: 128ms	remaining: 135ms
# 146:	learn: 0.2591183	total: 129ms	remaining: 134ms
# 147:	learn: 0.2577233	total: 129ms	remaining: 133ms
# 148:	learn: 0.2571241	total: 130ms	remaining: 131ms
# 149:	learn: 0.2553905	total: 130ms	remaining: 130ms
# 150:	learn: 0.2540904	total: 131ms	remaining: 129ms
# 151:	learn: 0.2529515	total: 131ms	remaining: 128ms
# 152:	learn: 0.2516239	total: 132ms	remaining: 127ms
# 153:	learn: 0.2506566	total: 133ms	remaining: 126ms
# 154:	learn: 0.2495767	total: 133ms	remaining: 125ms
# 155:	learn: 0.2490932	total: 134ms	remaining: 123ms
# 156:	learn: 0.2470999	total: 134ms	remaining: 122ms
# 157:	learn: 0.2458939	total: 135ms	remaining: 121ms
# 158:	learn: 0.2454747	total: 135ms	remaining: 120ms
# 159:	learn: 0.2443756	total: 136ms	remaining: 119ms
# 160:	learn: 0.2429766	total: 136ms	remaining: 118ms
# 161:	learn: 0.2418225	total: 137ms	remaining: 117ms
# 162:	learn: 0.2402799	total: 138ms	remaining: 116ms
# 163:	learn: 0.2387247	total: 138ms	remaining: 115ms
# 164:	learn: 0.2375999	total: 139ms	remaining: 113ms
# 165:	learn: 0.2359962	total: 139ms	remaining: 112ms
# 166:	learn: 0.2351529	total: 140ms	remaining: 111ms
# 167:	learn: 0.2338013	total: 140ms	remaining: 110ms
# 168:	learn: 0.2327119	total: 141ms	remaining: 109ms
# 169:	learn: 0.2315426	total: 142ms	remaining: 108ms
# 170:	learn: 0.2306642	total: 142ms	remaining: 107ms
# 171:	learn: 0.2305308	total: 143ms	remaining: 106ms
# 172:	learn: 0.2288049	total: 143ms	remaining: 105ms
# 173:	learn: 0.2280576	total: 144ms	remaining: 104ms
# 174:	learn: 0.2268279	total: 144ms	remaining: 103ms
# 175:	learn: 0.2259547	total: 145ms	remaining: 102ms
# 176:	learn: 0.2253874	total: 145ms	remaining: 101ms
# 177:	learn: 0.2240803	total: 146ms	remaining: 100ms
# 178:	learn: 0.2230201	total: 147ms	remaining: 99.1ms
# 179:	learn: 0.2221063	total: 147ms	remaining: 98.2ms
# 180:	learn: 0.2215591	total: 148ms	remaining: 97ms
# 181:	learn: 0.2205552	total: 148ms	remaining: 96ms
# 182:	learn: 0.2199875	total: 149ms	remaining: 95ms
# 183:	learn: 0.2186385	total: 149ms	remaining: 94ms
# 184:	learn: 0.2170830	total: 150ms	remaining: 93ms
# 185:	learn: 0.2160278	total: 150ms	remaining: 92.1ms
# 186:	learn: 0.2155551	total: 151ms	remaining: 91.1ms
# 187:	learn: 0.2147143	total: 151ms	remaining: 90.2ms
# 188:	learn: 0.2139324	total: 152ms	remaining: 89.3ms
# 189:	learn: 0.2124804	total: 153ms	remaining: 88.4ms
# 190:	learn: 0.2113483	total: 153ms	remaining: 87.5ms
# 191:	learn: 0.2103194	total: 154ms	remaining: 86.6ms
# 192:	learn: 0.2092457	total: 154ms	remaining: 85.6ms
# 193:	learn: 0.2087881	total: 155ms	remaining: 84.6ms
# 194:	learn: 0.2076055	total: 155ms	remaining: 83.7ms
# 195:	learn: 0.2064616	total: 156ms	remaining: 82.8ms
# 196:	learn: 0.2049358	total: 157ms	remaining: 81.9ms
# 197:	learn: 0.2041609	total: 157ms	remaining: 80.9ms
# 198:	learn: 0.2031459	total: 158ms	remaining: 80.1ms
# 199:	learn: 0.2022247	total: 159ms	remaining: 79.3ms
# 200:	learn: 0.2014408	total: 159ms	remaining: 78.4ms
# 201:	learn: 0.1998694	total: 160ms	remaining: 77.5ms
# 202:	learn: 0.1989066	total: 160ms	remaining: 76.6ms
# 203:	learn: 0.1981423	total: 161ms	remaining: 75.8ms
# 204:	learn: 0.1971645	total: 162ms	remaining: 74.9ms
# 205:	learn: 0.1962746	total: 162ms	remaining: 74.1ms
# 206:	learn: 0.1953080	total: 163ms	remaining: 73.1ms
# 207:	learn: 0.1936959	total: 163ms	remaining: 72.3ms
# 208:	learn: 0.1925857	total: 164ms	remaining: 71.5ms
# 209:	learn: 0.1914112	total: 165ms	remaining: 70.6ms
# 210:	learn: 0.1900265	total: 165ms	remaining: 69.8ms
# 211:	learn: 0.1893220	total: 166ms	remaining: 68.9ms
# 212:	learn: 0.1886617	total: 166ms	remaining: 68ms
# 213:	learn: 0.1875581	total: 167ms	remaining: 67.1ms
# 214:	learn: 0.1864526	total: 168ms	remaining: 66.3ms
# 215:	learn: 0.1858247	total: 168ms	remaining: 65.4ms
# 216:	learn: 0.1848242	total: 169ms	remaining: 64.5ms
# 217:	learn: 0.1838108	total: 169ms	remaining: 63.7ms
# 218:	learn: 0.1828708	total: 170ms	remaining: 62.8ms
# 219:	learn: 0.1819085	total: 170ms	remaining: 62ms
# 220:	learn: 0.1814205	total: 171ms	remaining: 61.2ms
# 221:	learn: 0.1807248	total: 172ms	remaining: 60.3ms
# 222:	learn: 0.1799375	total: 172ms	remaining: 59.4ms
# 223:	learn: 0.1790116	total: 173ms	remaining: 58.6ms
# 224:	learn: 0.1787860	total: 173ms	remaining: 57.8ms
# 225:	learn: 0.1779445	total: 174ms	remaining: 56.9ms
# 226:	learn: 0.1771117	total: 174ms	remaining: 56.1ms
# 227:	learn: 0.1762119	total: 175ms	remaining: 55.3ms
# 228:	learn: 0.1752970	total: 176ms	remaining: 54.5ms
# 229:	learn: 0.1747127	total: 176ms	remaining: 53.7ms
# 230:	learn: 0.1738463	total: 177ms	remaining: 52.8ms
# 231:	learn: 0.1732508	total: 177ms	remaining: 52ms
# 232:	learn: 0.1724807	total: 178ms	remaining: 51.2ms
# 233:	learn: 0.1716528	total: 179ms	remaining: 50.4ms
# 234:	learn: 0.1710092	total: 179ms	remaining: 49.6ms
# 235:	learn: 0.1704605	total: 180ms	remaining: 48.8ms
# 236:	learn: 0.1696471	total: 180ms	remaining: 47.9ms
# 237:	learn: 0.1688309	total: 181ms	remaining: 47.1ms
# 238:	learn: 0.1680555	total: 182ms	remaining: 46.4ms
# 239:	learn: 0.1673139	total: 182ms	remaining: 45.5ms
# 240:	learn: 0.1664323	total: 183ms	remaining: 44.7ms
# 241:	learn: 0.1660204	total: 183ms	remaining: 43.9ms
# 242:	learn: 0.1654272	total: 184ms	remaining: 43.2ms
# 243:	learn: 0.1647680	total: 185ms	remaining: 42.4ms
# 244:	learn: 0.1642077	total: 185ms	remaining: 41.5ms
# 245:	learn: 0.1636065	total: 186ms	remaining: 40.8ms
# 246:	learn: 0.1631831	total: 186ms	remaining: 39.9ms
# 247:	learn: 0.1627052	total: 187ms	remaining: 39.1ms
# 248:	learn: 0.1620629	total: 187ms	remaining: 38.3ms
# 249:	learn: 0.1617798	total: 188ms	remaining: 37.5ms
# 250:	learn: 0.1610613	total: 188ms	remaining: 36.7ms
# 251:	learn: 0.1602790	total: 189ms	remaining: 35.9ms
# 252:	learn: 0.1597119	total: 189ms	remaining: 35.2ms
# 253:	learn: 0.1585976	total: 190ms	remaining: 34.4ms
# 254:	learn: 0.1574109	total: 190ms	remaining: 33.6ms
# 255:	learn: 0.1566223	total: 191ms	remaining: 32.9ms
# 256:	learn: 0.1558046	total: 192ms	remaining: 32.1ms
# 257:	learn: 0.1551621	total: 193ms	remaining: 31.4ms
# 258:	learn: 0.1545468	total: 193ms	remaining: 30.6ms
# 259:	learn: 0.1537824	total: 194ms	remaining: 29.8ms
# 260:	learn: 0.1531995	total: 194ms	remaining: 29.1ms
# 261:	learn: 0.1527494	total: 195ms	remaining: 28.3ms
# 262:	learn: 0.1522662	total: 196ms	remaining: 27.5ms
# 263:	learn: 0.1516520	total: 196ms	remaining: 26.8ms
# 264:	learn: 0.1508026	total: 197ms	remaining: 26ms
# 265:	learn: 0.1499700	total: 198ms	remaining: 25.3ms
# 266:	learn: 0.1496295	total: 198ms	remaining: 24.5ms
# 267:	learn: 0.1488340	total: 199ms	remaining: 23.7ms
# 268:	learn: 0.1483445	total: 199ms	remaining: 22.9ms
# 269:	learn: 0.1478564	total: 200ms	remaining: 22.2ms
# 270:	learn: 0.1473105	total: 200ms	remaining: 21.4ms
# 271:	learn: 0.1467611	total: 201ms	remaining: 20.7ms
# 272:	learn: 0.1462373	total: 202ms	remaining: 20ms
# 273:	learn: 0.1456962	total: 202ms	remaining: 19.2ms
# 274:	learn: 0.1453408	total: 203ms	remaining: 18.4ms
# 275:	learn: 0.1452511	total: 203ms	remaining: 17.7ms
# 276:	learn: 0.1447829	total: 204ms	remaining: 16.9ms
# 277:	learn: 0.1442008	total: 204ms	remaining: 16.2ms
# 278:	learn: 0.1435218	total: 205ms	remaining: 15.4ms
# 279:	learn: 0.1428449	total: 205ms	remaining: 14.7ms
# 280:	learn: 0.1422647	total: 206ms	remaining: 13.9ms
# 281:	learn: 0.1418230	total: 207ms	remaining: 13.2ms
# 282:	learn: 0.1412266	total: 208ms	remaining: 12.5ms
# 283:	learn: 0.1407534	total: 208ms	remaining: 11.7ms
# 284:	learn: 0.1403084	total: 210ms	remaining: 11ms
# 285:	learn: 0.1397644	total: 210ms	remaining: 10.3ms
# 286:	learn: 0.1392504	total: 211ms	remaining: 9.56ms
# 287:	learn: 0.1389669	total: 212ms	remaining: 8.81ms
# 288:	learn: 0.1381081	total: 212ms	remaining: 8.07ms
# 289:	learn: 0.1373035	total: 213ms	remaining: 7.33ms
# 290:	learn: 0.1366538	total: 213ms	remaining: 6.59ms
# 291:	learn: 0.1358926	total: 214ms	remaining: 5.86ms
# 292:	learn: 0.1354576	total: 214ms	remaining: 5.12ms
# 293:	learn: 0.1349970	total: 215ms	remaining: 4.39ms
# 294:	learn: 0.1340050	total: 216ms	remaining: 3.65ms
# 295:	learn: 0.1337209	total: 216ms	remaining: 2.92ms
# 296:	learn: 0.1332448	total: 217ms	remaining: 2.19ms
# 297:	learn: 0.1327940	total: 217ms	remaining: 1.46ms
# 298:	learn: 0.1323024	total: 218ms	remaining: 728us
# 299:	learn: 0.1318022	total: 218ms	remaining: 0us
# Learning rate set to 0.012014
# 0:	learn: 0.6889528	total: 936us	remaining: 280ms
# 1:	learn: 0.6793100	total: 1.87ms	remaining: 279ms
# 2:	learn: 0.6722918	total: 2.31ms	remaining: 228ms
# 3:	learn: 0.6663815	total: 2.89ms	remaining: 214ms
# 4:	learn: 0.6592645	total: 3.42ms	remaining: 202ms
# 5:	learn: 0.6506159	total: 4.07ms	remaining: 199ms
# 6:	learn: 0.6445902	total: 4.67ms	remaining: 196ms
# 7:	learn: 0.6387243	total: 5.24ms	remaining: 191ms
# 8:	learn: 0.6324696	total: 5.85ms	remaining: 189ms
# 9:	learn: 0.6261688	total: 6.51ms	remaining: 189ms
# 10:	learn: 0.6186267	total: 7.07ms	remaining: 186ms
# 11:	learn: 0.6129111	total: 7.63ms	remaining: 183ms
# 12:	learn: 0.6057618	total: 8.18ms	remaining: 181ms
# 13:	learn: 0.5988392	total: 8.75ms	remaining: 179ms
# 14:	learn: 0.5924253	total: 9.4ms	remaining: 179ms
# 15:	learn: 0.5872333	total: 10ms	remaining: 178ms
# 16:	learn: 0.5812621	total: 10.7ms	remaining: 178ms
# 17:	learn: 0.5775612	total: 11.1ms	remaining: 173ms
# 18:	learn: 0.5729067	total: 11.3ms	remaining: 168ms
# 19:	learn: 0.5667661	total: 11.9ms	remaining: 167ms
# 20:	learn: 0.5604563	total: 12.5ms	remaining: 166ms
# 21:	learn: 0.5564899	total: 13.1ms	remaining: 166ms
# 22:	learn: 0.5502525	total: 13.6ms	remaining: 164ms
# 23:	learn: 0.5445456	total: 14.3ms	remaining: 165ms
# 24:	learn: 0.5380871	total: 14.9ms	remaining: 164ms
# 25:	learn: 0.5337626	total: 15.4ms	remaining: 162ms
# 26:	learn: 0.5291332	total: 16.1ms	remaining: 162ms
# 27:	learn: 0.5250897	total: 16.6ms	remaining: 161ms
# 28:	learn: 0.5206246	total: 17.1ms	remaining: 160ms
# 29:	learn: 0.5161475	total: 17.9ms	remaining: 161ms
# 30:	learn: 0.5124332	total: 18.5ms	remaining: 161ms
# 31:	learn: 0.5080946	total: 19.1ms	remaining: 160ms
# 32:	learn: 0.5026119	total: 19.6ms	remaining: 159ms
# 33:	learn: 0.4974338	total: 20.3ms	remaining: 159ms
# 34:	learn: 0.4935989	total: 20.9ms	remaining: 158ms
# 35:	learn: 0.4887858	total: 21.4ms	remaining: 157ms
# 36:	learn: 0.4845679	total: 22ms	remaining: 157ms
# 37:	learn: 0.4793667	total: 22.7ms	remaining: 157ms
# 38:	learn: 0.4758207	total: 23.3ms	remaining: 156ms
# 39:	learn: 0.4721059	total: 23.9ms	remaining: 155ms
# 40:	learn: 0.4685244	total: 24.5ms	remaining: 155ms
# 41:	learn: 0.4644706	total: 25.1ms	remaining: 154ms
# 42:	learn: 0.4606153	total: 25.7ms	remaining: 154ms
# 43:	learn: 0.4555061	total: 26.4ms	remaining: 154ms
# 44:	learn: 0.4517662	total: 27ms	remaining: 153ms
# 45:	learn: 0.4485476	total: 27.5ms	remaining: 152ms
# 46:	learn: 0.4445600	total: 28ms	remaining: 151ms
# 47:	learn: 0.4410823	total: 28.7ms	remaining: 151ms
# 48:	learn: 0.4398090	total: 29ms	remaining: 148ms
# 49:	learn: 0.4362857	total: 29.5ms	remaining: 147ms
# 50:	learn: 0.4333696	total: 30.1ms	remaining: 147ms
# 51:	learn: 0.4292781	total: 30.6ms	remaining: 146ms
# 52:	learn: 0.4268278	total: 31.2ms	remaining: 145ms
# 53:	learn: 0.4243134	total: 32.4ms	remaining: 148ms
# 54:	learn: 0.4214430	total: 33ms	remaining: 147ms
# 55:	learn: 0.4186844	total: 33.7ms	remaining: 147ms
# 56:	learn: 0.4152458	total: 34.2ms	remaining: 146ms
# 57:	learn: 0.4136833	total: 34.7ms	remaining: 145ms
# 58:	learn: 0.4109625	total: 35.4ms	remaining: 145ms
# 59:	learn: 0.4078293	total: 36ms	remaining: 144ms
# 60:	learn: 0.4046855	total: 36.6ms	remaining: 143ms
# 61:	learn: 0.4024209	total: 37.1ms	remaining: 143ms
# 62:	learn: 0.3998917	total: 37.9ms	remaining: 143ms
# 63:	learn: 0.3975914	total: 38.6ms	remaining: 142ms
# 64:	learn: 0.3953743	total: 39.2ms	remaining: 142ms
# 65:	learn: 0.3931277	total: 39.9ms	remaining: 141ms
# 66:	learn: 0.3894579	total: 40.5ms	remaining: 141ms
# 67:	learn: 0.3854890	total: 41ms	remaining: 140ms
# 68:	learn: 0.3819303	total: 41.6ms	remaining: 139ms
# 69:	learn: 0.3789974	total: 42.2ms	remaining: 139ms
# 70:	learn: 0.3773546	total: 42.8ms	remaining: 138ms
# 71:	learn: 0.3748638	total: 43.3ms	remaining: 137ms
# 72:	learn: 0.3714564	total: 43.9ms	remaining: 137ms
# 73:	learn: 0.3692181	total: 44.3ms	remaining: 135ms
# 74:	learn: 0.3662470	total: 44.9ms	remaining: 135ms
# 75:	learn: 0.3641248	total: 45.5ms	remaining: 134ms
# 76:	learn: 0.3618708	total: 46ms	remaining: 133ms
# 77:	learn: 0.3589085	total: 46.5ms	remaining: 132ms
# 78:	learn: 0.3560497	total: 47.1ms	remaining: 132ms
# 79:	learn: 0.3534190	total: 47.7ms	remaining: 131ms
# 80:	learn: 0.3497264	total: 48.3ms	remaining: 131ms
# 81:	learn: 0.3467703	total: 48.9ms	remaining: 130ms
# 82:	learn: 0.3441779	total: 49.6ms	remaining: 130ms
# 83:	learn: 0.3429753	total: 50.3ms	remaining: 129ms
# 84:	learn: 0.3416802	total: 50.7ms	remaining: 128ms
# 85:	learn: 0.3395966	total: 51.2ms	remaining: 127ms
# 86:	learn: 0.3372559	total: 51.7ms	remaining: 127ms
# 87:	learn: 0.3352060	total: 52.5ms	remaining: 126ms
# 88:	learn: 0.3323686	total: 53ms	remaining: 126ms
# 89:	learn: 0.3300909	total: 53.6ms	remaining: 125ms
# 90:	learn: 0.3277391	total: 54.1ms	remaining: 124ms
# 91:	learn: 0.3261704	total: 54.7ms	remaining: 124ms
# 92:	learn: 0.3241162	total: 55.3ms	remaining: 123ms
# 93:	learn: 0.3217347	total: 55.9ms	remaining: 123ms
# 94:	learn: 0.3202474	total: 56.4ms	remaining: 122ms
# 95:	learn: 0.3181387	total: 56.9ms	remaining: 121ms
# 96:	learn: 0.3172263	total: 58.3ms	remaining: 122ms
# 97:	learn: 0.3151342	total: 58.8ms	remaining: 121ms
# 98:	learn: 0.3131789	total: 59.4ms	remaining: 121ms
# 99:	learn: 0.3119838	total: 60.8ms	remaining: 122ms
# 100:	learn: 0.3099223	total: 61.4ms	remaining: 121ms
# 101:	learn: 0.3081705	total: 62ms	remaining: 120ms
# 102:	learn: 0.3064680	total: 62.5ms	remaining: 120ms
# 103:	learn: 0.3047667	total: 63ms	remaining: 119ms
# 104:	learn: 0.3032027	total: 63.8ms	remaining: 119ms
# 105:	learn: 0.3025512	total: 64.2ms	remaining: 117ms
# 106:	learn: 0.3002726	total: 64.9ms	remaining: 117ms
# 107:	learn: 0.2989885	total: 65.4ms	remaining: 116ms
# 108:	learn: 0.2975339	total: 66ms	remaining: 116ms
# 109:	learn: 0.2956986	total: 66.7ms	remaining: 115ms
# 110:	learn: 0.2943872	total: 67.3ms	remaining: 115ms
# 111:	learn: 0.2918899	total: 67.9ms	remaining: 114ms
# 112:	learn: 0.2896268	total: 68.5ms	remaining: 113ms
# 113:	learn: 0.2885200	total: 69ms	remaining: 113ms
# 114:	learn: 0.2872875	total: 69.6ms	remaining: 112ms
# 115:	learn: 0.2858596	total: 70.1ms	remaining: 111ms
# 116:	learn: 0.2847808	total: 70.6ms	remaining: 110ms
# 117:	learn: 0.2835758	total: 71.3ms	remaining: 110ms
# 118:	learn: 0.2815029	total: 71.9ms	remaining: 109ms
# 119:	learn: 0.2799623	total: 72.5ms	remaining: 109ms
# 120:	learn: 0.2785680	total: 73.1ms	remaining: 108ms
# 121:	learn: 0.2770227	total: 73.7ms	remaining: 108ms
# 122:	learn: 0.2759062	total: 74.4ms	remaining: 107ms
# 123:	learn: 0.2744548	total: 75ms	remaining: 106ms
# 124:	learn: 0.2728741	total: 76ms	remaining: 106ms
# 125:	learn: 0.2722666	total: 76.6ms	remaining: 106ms
# 126:	learn: 0.2711332	total: 77.3ms	remaining: 105ms
# 127:	learn: 0.2692712	total: 77.8ms	remaining: 105ms
# 128:	learn: 0.2679149	total: 78.4ms	remaining: 104ms
# 129:	learn: 0.2658573	total: 79.1ms	remaining: 103ms
# 130:	learn: 0.2635888	total: 79.6ms	remaining: 103ms
# 131:	learn: 0.2619310	total: 80.1ms	remaining: 102ms
# 132:	learn: 0.2605116	total: 80.7ms	remaining: 101ms
# 133:	learn: 0.2590322	total: 81.3ms	remaining: 101ms
# 134:	learn: 0.2572724	total: 81.9ms	remaining: 100ms
# 135:	learn: 0.2561048	total: 82.4ms	remaining: 99.4ms
# 136:	learn: 0.2545312	total: 82.9ms	remaining: 98.6ms
# 137:	learn: 0.2527361	total: 83.4ms	remaining: 98ms
# 138:	learn: 0.2511130	total: 84ms	remaining: 97.3ms
# 139:	learn: 0.2501673	total: 84.6ms	remaining: 96.7ms
# 140:	learn: 0.2489087	total: 85.1ms	remaining: 96ms
# 141:	learn: 0.2476000	total: 85.7ms	remaining: 95.4ms
# 142:	learn: 0.2466077	total: 86.3ms	remaining: 94.7ms
# 143:	learn: 0.2454213	total: 86.9ms	remaining: 94.2ms
# 144:	learn: 0.2440645	total: 87.4ms	remaining: 93.4ms
# 145:	learn: 0.2432538	total: 88ms	remaining: 92.8ms
# 146:	learn: 0.2420938	total: 88.7ms	remaining: 92.3ms
# 147:	learn: 0.2412883	total: 89.2ms	remaining: 91.6ms
# 148:	learn: 0.2395392	total: 89.9ms	remaining: 91.1ms
# 149:	learn: 0.2380286	total: 90.5ms	remaining: 90.5ms
# 150:	learn: 0.2371701	total: 91.2ms	remaining: 90ms
# 151:	learn: 0.2356158	total: 91.7ms	remaining: 89.2ms
# 152:	learn: 0.2340892	total: 92.3ms	remaining: 88.6ms
# 153:	learn: 0.2328305	total: 92.9ms	remaining: 88.1ms
# 154:	learn: 0.2313120	total: 93.5ms	remaining: 87.5ms
# 155:	learn: 0.2307594	total: 94.1ms	remaining: 86.8ms
# 156:	learn: 0.2295278	total: 94.6ms	remaining: 86.2ms
# 157:	learn: 0.2279726	total: 95.2ms	remaining: 85.5ms
# 158:	learn: 0.2262652	total: 95.7ms	remaining: 84.9ms
# 159:	learn: 0.2253142	total: 96.3ms	remaining: 84.3ms
# 160:	learn: 0.2242100	total: 97ms	remaining: 83.8ms
# 161:	learn: 0.2225680	total: 97.7ms	remaining: 83.3ms
# 162:	learn: 0.2217062	total: 99ms	remaining: 83.2ms
# 163:	learn: 0.2200553	total: 99.5ms	remaining: 82.5ms
# 164:	learn: 0.2194946	total: 100ms	remaining: 81.9ms
# 165:	learn: 0.2176862	total: 101ms	remaining: 81.2ms
# 166:	learn: 0.2167058	total: 101ms	remaining: 80.6ms
# 167:	learn: 0.2153631	total: 102ms	remaining: 80ms
# 168:	learn: 0.2141992	total: 102ms	remaining: 79.4ms
# 169:	learn: 0.2128250	total: 103ms	remaining: 78.9ms
# 170:	learn: 0.2116675	total: 104ms	remaining: 78.3ms
# 171:	learn: 0.2105050	total: 104ms	remaining: 77.7ms
# 172:	learn: 0.2094305	total: 105ms	remaining: 77.2ms
# 173:	learn: 0.2085811	total: 106ms	remaining: 76.6ms
# 174:	learn: 0.2074515	total: 106ms	remaining: 76ms
# 175:	learn: 0.2063699	total: 108ms	remaining: 75.8ms
# 176:	learn: 0.2053805	total: 108ms	remaining: 75.1ms
# 177:	learn: 0.2039118	total: 109ms	remaining: 74.5ms
# 178:	learn: 0.2027642	total: 109ms	remaining: 73.8ms
# 179:	learn: 0.2018816	total: 110ms	remaining: 73.2ms
# 180:	learn: 0.2011715	total: 112ms	remaining: 73.4ms
# 181:	learn: 0.2001832	total: 113ms	remaining: 73.2ms
# 182:	learn: 0.1996222	total: 114ms	remaining: 72.6ms
# 183:	learn: 0.1988104	total: 114ms	remaining: 71.9ms
# 184:	learn: 0.1975984	total: 115ms	remaining: 71.2ms
# 185:	learn: 0.1968542	total: 115ms	remaining: 70.5ms
# 186:	learn: 0.1960141	total: 116ms	remaining: 69.9ms
# 187:	learn: 0.1950706	total: 116ms	remaining: 69.2ms
# 188:	learn: 0.1942191	total: 117ms	remaining: 68.6ms
# 189:	learn: 0.1938171	total: 117ms	remaining: 68ms
# 190:	learn: 0.1929798	total: 119ms	remaining: 67.8ms
# 191:	learn: 0.1923142	total: 119ms	remaining: 67.1ms
# 192:	learn: 0.1912046	total: 120ms	remaining: 66.5ms
# 193:	learn: 0.1903906	total: 120ms	remaining: 65.8ms
# 194:	learn: 0.1891056	total: 121ms	remaining: 65.1ms
# 195:	learn: 0.1884693	total: 121ms	remaining: 64.4ms
# 196:	learn: 0.1878710	total: 122ms	remaining: 63.8ms
# 197:	learn: 0.1870558	total: 122ms	remaining: 63.1ms
# 198:	learn: 0.1861486	total: 123ms	remaining: 62.5ms
# 199:	learn: 0.1855163	total: 123ms	remaining: 61.7ms
# 200:	learn: 0.1850687	total: 124ms	remaining: 61ms
# 201:	learn: 0.1841929	total: 124ms	remaining: 60.4ms
# 202:	learn: 0.1837723	total: 125ms	remaining: 59.8ms
# 203:	learn: 0.1830477	total: 126ms	remaining: 59.1ms
# 204:	learn: 0.1823902	total: 126ms	remaining: 58.5ms
# 205:	learn: 0.1815147	total: 127ms	remaining: 57.9ms
# 206:	learn: 0.1809992	total: 127ms	remaining: 57.2ms
# 207:	learn: 0.1802659	total: 128ms	remaining: 56.6ms
# 208:	learn: 0.1791491	total: 128ms	remaining: 55.9ms
# 209:	learn: 0.1782989	total: 129ms	remaining: 55.3ms
# 210:	learn: 0.1773519	total: 130ms	remaining: 54.6ms
# 211:	learn: 0.1767383	total: 130ms	remaining: 54ms
# 212:	learn: 0.1762496	total: 131ms	remaining: 53.3ms
# 213:	learn: 0.1753733	total: 131ms	remaining: 52.7ms
# 214:	learn: 0.1745568	total: 132ms	remaining: 52.1ms
# 215:	learn: 0.1737769	total: 132ms	remaining: 51.5ms
# 216:	learn: 0.1732253	total: 133ms	remaining: 50.9ms
# 217:	learn: 0.1731120	total: 133ms	remaining: 50.2ms
# 218:	learn: 0.1723244	total: 134ms	remaining: 49.6ms
# 219:	learn: 0.1717467	total: 135ms	remaining: 49ms
# 220:	learn: 0.1714795	total: 135ms	remaining: 48.4ms
# 221:	learn: 0.1708779	total: 136ms	remaining: 47.8ms
# 222:	learn: 0.1702683	total: 137ms	remaining: 47.2ms
# 223:	learn: 0.1692848	total: 137ms	remaining: 46.6ms
# 224:	learn: 0.1685803	total: 138ms	remaining: 46ms
# 225:	learn: 0.1679897	total: 139ms	remaining: 45.4ms
# 226:	learn: 0.1679391	total: 139ms	remaining: 44.6ms
# 227:	learn: 0.1671685	total: 139ms	remaining: 44ms
# 228:	learn: 0.1666379	total: 140ms	remaining: 43.4ms
# 229:	learn: 0.1658521	total: 141ms	remaining: 42.8ms
# 230:	learn: 0.1650145	total: 141ms	remaining: 42.1ms
# 231:	learn: 0.1641060	total: 142ms	remaining: 41.5ms
# 232:	learn: 0.1633264	total: 142ms	remaining: 40.9ms
# 233:	learn: 0.1625469	total: 143ms	remaining: 40.3ms
# 234:	learn: 0.1615165	total: 143ms	remaining: 39.7ms
# 235:	learn: 0.1610777	total: 144ms	remaining: 39ms
# 236:	learn: 0.1604174	total: 144ms	remaining: 38.4ms
# 237:	learn: 0.1594793	total: 145ms	remaining: 37.8ms
# 238:	learn: 0.1589910	total: 146ms	remaining: 37.3ms
# 239:	learn: 0.1583514	total: 147ms	remaining: 36.7ms
# 240:	learn: 0.1576135	total: 147ms	remaining: 36.1ms
# 241:	learn: 0.1567838	total: 148ms	remaining: 35.5ms
# 242:	learn: 0.1559051	total: 149ms	remaining: 34.9ms
# 243:	learn: 0.1554078	total: 149ms	remaining: 34.2ms
# 244:	learn: 0.1549453	total: 150ms	remaining: 33.6ms
# 245:	learn: 0.1541425	total: 150ms	remaining: 33ms
# 246:	learn: 0.1534468	total: 151ms	remaining: 32.4ms
# 247:	learn: 0.1528695	total: 152ms	remaining: 31.8ms
# 248:	learn: 0.1523289	total: 152ms	remaining: 31.1ms
# 249:	learn: 0.1514258	total: 153ms	remaining: 30.5ms
# 250:	learn: 0.1506619	total: 154ms	remaining: 30.1ms
# 251:	learn: 0.1499699	total: 155ms	remaining: 29.4ms
# 252:	learn: 0.1492516	total: 155ms	remaining: 28.8ms
# 253:	learn: 0.1486716	total: 156ms	remaining: 28.2ms
# 254:	learn: 0.1480770	total: 156ms	remaining: 27.6ms
# 255:	learn: 0.1474378	total: 158ms	remaining: 27.1ms
# 256:	learn: 0.1466011	total: 158ms	remaining: 26.5ms
# 257:	learn: 0.1459801	total: 160ms	remaining: 26ms
# 258:	learn: 0.1457056	total: 160ms	remaining: 25.4ms
# 259:	learn: 0.1450534	total: 161ms	remaining: 24.7ms
# 260:	learn: 0.1444491	total: 161ms	remaining: 24.1ms
# 261:	learn: 0.1440853	total: 162ms	remaining: 23.5ms
# 262:	learn: 0.1433726	total: 163ms	remaining: 22.9ms
# 263:	learn: 0.1424307	total: 163ms	remaining: 22.3ms
# 264:	learn: 0.1415353	total: 164ms	remaining: 21.6ms
# 265:	learn: 0.1415155	total: 164ms	remaining: 21ms
# 266:	learn: 0.1407659	total: 165ms	remaining: 20.4ms
# 267:	learn: 0.1401180	total: 165ms	remaining: 19.8ms
# 268:	learn: 0.1395027	total: 166ms	remaining: 19.1ms
# 269:	learn: 0.1394533	total: 166ms	remaining: 18.5ms
# 270:	learn: 0.1389424	total: 167ms	remaining: 17.9ms
# 271:	learn: 0.1383998	total: 167ms	remaining: 17.2ms
# 272:	learn: 0.1378733	total: 168ms	remaining: 16.6ms
# 273:	learn: 0.1371732	total: 168ms	remaining: 16ms
# 274:	learn: 0.1365785	total: 169ms	remaining: 15.4ms
# 275:	learn: 0.1360161	total: 170ms	remaining: 14.8ms
# 276:	learn: 0.1357646	total: 170ms	remaining: 14.1ms
# 277:	learn: 0.1355314	total: 171ms	remaining: 13.5ms
# 278:	learn: 0.1351925	total: 171ms	remaining: 12.9ms
# 279:	learn: 0.1346008	total: 172ms	remaining: 12.3ms
# 280:	learn: 0.1338296	total: 173ms	remaining: 11.7ms
# 281:	learn: 0.1333541	total: 173ms	remaining: 11.1ms
# 282:	learn: 0.1332614	total: 174ms	remaining: 10.4ms
# 283:	learn: 0.1326731	total: 174ms	remaining: 9.82ms
# 284:	learn: 0.1322563	total: 175ms	remaining: 9.21ms
# 285:	learn: 0.1317503	total: 176ms	remaining: 8.6ms
# 286:	learn: 0.1311809	total: 176ms	remaining: 7.98ms
# 287:	learn: 0.1308542	total: 177ms	remaining: 7.37ms
# 288:	learn: 0.1303167	total: 178ms	remaining: 6.76ms
# 289:	learn: 0.1296914	total: 178ms	remaining: 6.16ms
# 290:	learn: 0.1291098	total: 179ms	remaining: 5.54ms
# 291:	learn: 0.1283055	total: 180ms	remaining: 4.93ms
# 292:	learn: 0.1278727	total: 180ms	remaining: 4.31ms
# 293:	learn: 0.1274271	total: 181ms	remaining: 3.69ms
# 294:	learn: 0.1270364	total: 182ms	remaining: 3.08ms
# 295:	learn: 0.1265870	total: 182ms	remaining: 2.46ms
# 296:	learn: 0.1260190	total: 183ms	remaining: 1.85ms
# 297:	learn: 0.1251214	total: 183ms	remaining: 1.23ms
# 298:	learn: 0.1249639	total: 184ms	remaining: 615us
# 299:	learn: 0.1245342	total: 185ms	remaining: 0us

# %%
NFL.fit_model.feature_names_
# Out:
# ['round',
#  'pick',
#  'season',
#  'G',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'Yds',
#  'TD',
#  'TD%',
#  'Int',
#  'Int%',
#  'Y/A',
#  'AY/A',
#  'Y/C',
#  'Y/G',
#  'Rate',
#  'seasons',
#  'recent_team']

# %%
joblib.dump(NFL.fit_model, '/Users/benstager/Desktop/mfl_project/mfl/api/saved_models/catboost_v_0_0.pkl')
# Out:
# ['/Users/benstager/Desktop/mfl_project/mfl/api/saved_models/catboost_v_0_0.pkl']

# %%
model = joblib.load('/Users/benstager/Desktop/mfl_project/mfl/api/saved_models/catboost_v_0_0.pkl')

# %%
model.feature_names_
# Out:
# ['pfr_player_name',
#  'round',
#  'pick',
#  'season',
#  'G',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'Yds',
#  'TD',
#  'TD%',
#  'Int',
#  'Int%',
#  'Y/A',
#  'AY/A',
#  'Y/C',
#  'Y/G',
#  'Rate',
#  'seasons',
#  'name',
#  'recent_team']

# %%
shedeur.columns
# Out:
# Index(['G', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'TD%', 'Int', 'Int%', 'Y/A',
#        'AY/A', 'Y/C', 'Y/G', 'Rate', 'seasons', 'name'],
#       dtype='object')

# %%
shedeur = mfldata.scrape_NFL_REF_QB(player_name='Shedeur Sanders')
